# %%
pwd
# Out:
# u'C:\\Users\\Luisa\\.xy\\startups'

# %%
cd
# Out:
# C:\Users\Luisa

# %%
cd C:\Users\Luisa\Documents\GitHub\MscCodingSprint13\Cloud Computing
# Out:
# C:\Users\Luisa\Documents\GitHub\MscCodingSprint13\Cloud Computing

# %% [markdown]
# # Cloud Computing

# %% [markdown]
# ### Amazon EC2 - creating a Key Pair and an Instance

# %% [markdown]
# 1 - Create an account at Web Services Amazon http://aws.amazon.com/ec2/.

# %% [markdown]
# 2 -Before to create an instance it is necessary to create a Key Pair in the option **EC2 Dashboard -> Create Key Pair**. In this stage it will be created a file *.pem*. and this document will be used in the next steps, by your new instance.

# %% [markdown]
# ![my_image](./1.png)
#
#
# ![aas]("1.png")

# %% [markdown]
# 3 -In **My Account/Console** choose **AWS Management Console**.

# %%
from IPython.display import Image
Image(filename='2.png')

# %% [markdown]
# 4 -In the Amazon Web Services choose **EC2 Virtual Servers in the Cloud**.

# %%
Image(filename='3.png')

# %% [markdown]
# 5 -Ensure that the location used is **EU (Ireland)**. <br />
# 6 -Create a new instance at **Launch Instance** or choose **INSTANCES -> Instances** if an instance has already been created. <br />
# 7 -As example to create a new instance, after Launch Instance option, choose:  <br />
# <ol>
# <li>Classic Wizard;</li>
# <li>Ubuntu Server 12.04.1 LTS and 64 bits.</li>
# <li>Instance Type: T1 Micro (t1.micro, 613 MiB); Launch into EC2;</li>
# <li>Continue until you reach the Review tab;</li>
# <li>Choose your existing key pair or create a new one. In this stage you must select the key pair that you already created before;</li>
# <li>Continue and Finish;</li>
# </ol>

# %%
Image(filename='4.png')

# %%
Image(filename='5.png')

# %%
Image(filename='6.png')

# %%
Image(filename='7.png')

# %% [markdown]
# 8 -Select the instance and choose **Start**.</br>
# 9 -Choose **Connect** and copy the **localhoost**. Example: *root@ec2-54-246-67-207.eu-west-1.compute.amazonaws.com*.

# %%
Image(filename='8.png')

# %%
Image(filename='9.png')

# %% [markdown]
# At this point the instances have been started and are ready to be used. Communication can be done using the PuTTy or the Bitvise terminals.

# %% [markdown]
# #### Considerations:

# %% [markdown]
# <ol>
# <li>Ensure that the Volumes capacity doesn’t exceed 30 Gbytes;</li>
# <li>Select one Security Group (ex: quicklaunch-1);</li>
# <li>Elastic IP – This allows to use the localhoost in a different format (which is paid). Choose Allocate New Address -> Associate New Address and select the created instance; </li>
# <li>After using the instance ensure that they are Stopped;</li>
# </ol>

# %%
Image(filename='10.png')

# %% [markdown]
# ### Bitvise – connecting the instance with your virtual machine

# %% [markdown]
# 1 -The terminal can be downloaded from:  *https://www.bitvise.com/ssh-client-download*.</br>
# 2 -Install the latest version. Open Bitvise and define its configurations as defined in the image:

# %%
Image(filename='11.png')

# %% [markdown]
# 3 -In this stage you need to ensure that your instance is running.

# %% [markdown]
# 4 -In the Bitvise console, insert the host and the username as presented in the following image.  Insert “*ubuntu*” as *username* and the **PUBLIC DNS**, present in the **Description of the Instance**, in the *host* space. Example: host - *ec2-54-216-34-108.eu-west-1.compute.amazonaws.com*.

# %%
Image(filename='12.png')

# %% [markdown]
# 5 -In the **user keypair manager**, load the *.pem* file created previously.

# %%
Image(filename='13.png')

# %% [markdown]
# 6 -There will be a console which connects your pc to your virtual machine in the final stage.

# %%
Image(filename='14.png')

# %% [markdown]
# ### Required Installations for the instances

# %% [markdown]
# To proceed to parallel processing it is necessary to install all files and programs required to compute your code. The following commands must be written in the Bitvise window as represented below.

# %%
Image(filename='16.png')

# %% [markdown]
# 1 -Install iPython and Notebook

# %% [raw]
# $ sudo apt-get install ipython python-scipy matplotlib python-h5py ipython-notebook
# $ sudo apt-get install python-dev python-numpy python-numpy-dev python-setuptools python-numpy-dev python-scipy libatlas-dev g++
# $ sudo apt-get install python-pip
# $ sudo pip install ipython --upgrade

# %% [markdown]
# 2 -Install ScikitLearn

# %% [raw]
# $ sudo easy_install nose
# $ sudo easy_install -U scikit-learn

# %% [markdown]
# 3 -Install git and novainstrumentation

# %% [raw]
# $ sudo apt-get install git

# %% [markdown]
# 4- Connect the novainstrumentation library present in the github

# %%
Image(filename='17.png')

# %% [raw]
# $ git clone https://github.com/hgamboa/novainstrumentation.git

# %% [markdown]
# 5 -To change directory of novainstrumentation (edit profile and add):

# %% [raw]
# PYTHONPATH="${PYTHONPATH}:~
# export PYTHONPATH

# %% [markdown]
# ### Open Notebook in browser

# %% [markdown]
# This notebook creation allows you to program in python to communicate with the cloud. This stage can be used instead of the Bitvise console.

# %% [markdown]
# See *http://ipython.org/ipython-doc/dev/interactive/htmlnotebook.html* for more details. You can protect your notebook server with a simple single-password by setting the NotebookApp.password configurable. You can prepare a hashed password using the function **IPython.lib.security.passwd()**:

# %% [raw]
# In [1]: from IPython.lib import passwd
# In [2]: passwd()
# Enter password:
# Verify password: Out[2]:'sha1:67c9e60bb8b6:9ffede0825894254b2e042ea597d771089e11aed'

# %% [markdown]
# When using a password, it is a good idea to also use SSL, so that your password is not sent unencrypted by your browser. You can start the notebook to communicate via a secure protocol mode using a self-signed certificate by typing:

# %% [raw]
# $ ipython notebook --certfile=mycert.pem

# %% [markdown]
# A self-signed certificate can be generated with openssl. For example, the following command will create a certificate valid for 365 days with both the key and certificate data written to the same file:

# %% [raw]
# $ openssl req -x509 -nodes -days 365 -newkey rsa:1024 -keyout mycert.pem -out mycert.pem

# %% [markdown]
# The process to create a password only needs to be done once.</br> If you want to access your notebook server remotely with just a web browser, here is a quick set of instructions. Start by creating a certificate file and a hashed password as explained above. Then, create a custom profile for the notebook. At the command line, type:

# %% [markdown]
# ipython profile create nbserver

# %% [raw]
# sudo vi .ipython/profile_nbserver/ipython_notebook_config.py

# %% [markdown]
# In the profile directory, edit the file ipython_notebook_config.py. By default the file has all fields commented, the minimum set you need to uncomment and edit is here:

# %% [raw]
# c = get_config()
#
# # Kernel config c.IPKernelApp.pylab = 'inline' # if you want plotting support always
#
# # Notebook config
# c.NotebookApp.certfile = u'/absolute/path/to/your/certificate/mycert.pem' c.NotebookApp.ip = '*'
# c.NotebookApp.open_browser = False
# c.NotebookApp.password = u'sha1:bcd259ccf...your hashed password here'
# # It's a good idea to put it on a known, fixed port
# c.NotebookApp.port = 80

# %% [markdown]
# You can then start the notebook and access it later (using the created password) by pointing your browser to https://your.host.com:80 with sudo ipython notebook --profile=nbserver. </br>
#
# Example: *https://ec2-54-228-8-143.eu-west-1.compute.amazonaws.com:80*

# %% [markdown]
# ### Linux Commands

# %% [markdown]
# Use http://www.ee.surrey.ac.uk/Teaching/Unix/unixintro.html and http://scipher.wordpress.com/2010/05/10/setting-your-pythonpath-environment-variable-linuxunixosx/ for more details and exercises.</br></br>
# </ol>
# <li>ipython – Opens python console;</li>
# <li>vi file – Edit file;</li>
# <li>ESC – Leaves edit mode;</li>
# <li>SHIFT !wq – Leaves file and saves changes;</li>
# <li>CTRL z – Leaves the program/suspends;</li>
# <li>sudo – super user;</li>
# <li>fg – forward ground;</li>
# <li>bg – background;</li>
# <li>cd directory – changes directory (just cd goes home);</li>
# <li>chmod – files permissions;</li>
# <li>ls – list all files in a directory;</li>
# <li>ls –a – list all files in a directory (even hidden files);</li>
# <li>sudo ipython notebook –profile=nbserver – To open notebook;</li>
# <li>ps –la – current running processes;</li>
# <li>kill -9 PPID – Kills a process;</li>
# </ol>
